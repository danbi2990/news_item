# %%
import urllib.parse

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

import src.mongos as mg

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Const

# %%
url_seats = 'http://www.kobis.or.kr/kobis/business/stat/boxs/findDailySeatTicketList.do'

# %%
params = {
    'loadEnd':'0',
    'totSeatCntRatioOrder':'',
    'totSeatCntOrder':'',
    'totShowAmtOrder':'',
    'addTotShowAmtOrder':'',
    'totShowCntOrder':'',
    'addTotShowCntOrder':'',
    'dmlMode':'search',
    'startDate':'2019-05-03',
    'endDate':'',
    'searchType':'',
    'repNationCd':'',
    'wideareaCd':'',
}

r = requests.post(url_seats, data=params)

# %%
tables = pd.read_html(r.text)
len(tables)
# Out:
# 4

# %%
tables[0]
# Out:
#    순위                               영화명         개봉일 좌석판매율  오름차순  내림차순  \
# 0  1   어벤져스: 엔드게임                        2019-04-24  50.2%
# 1  2   나의 특별한 형제                         2019-05-01  43.6%
# 2  3   뽀로로 극장판 보물섬 대모험                   2019-04-25  35.6%
# 3  4   어글리 돌                             2019-05-01  16.6%
# 4  5   프렌즈: 둥지탈출                         2019-05-01  10.0%
# 5  6   캡틴 마블                             2019-03-06  22.5%
# 6  7   생일                                2019-04-03  12.3%
# 7  8   노팅 힐                              1999-07-03  13.4%
# 8  9   킹 오브 프리즘 -샤이니 세븐 스타즈- Ⅲ 레오×유우×알렉  2019-05-02  24.1%
# 9  10  미성년                               2019-04-11  25.7%
#
#   좌석점유율  오름차순  내림차순  좌석수  오름차순  내림차순  매출액  오름차순  내림차순  누적매출액  오름차순  내림차순  \
# 0  66.1%             1791949          8137942240       87138344020
# 1  12.4%             336746           1257365950       3922896210
# 2  7.8%              212695           597767930        3801672060
# 3  1.4%              38789            49157450         207269840
# 4  0.6%              16968            12597800         57576550
# 5  0.3%              8775             17681450         51435128863
# 6  0.3%              6985             6604610          9835889440
# 7  0.2%              5183             6244600          477726882
# 8  0.2%              4584             9990680          27728100
# 9  0.1%              3434             7917680          2446244340
#
#    관객수  오름차순  내림차순  누적관객수  오름차순  내림차순
# 0  899958           10086464
# 1  146797           486212
# 2  75621            499829
# 3  6442             29071
# 4  1691             8610
# 5  1975             5794498
# 6  857              1190465
# 7  695              57805
# 8  1106             3258
# 9  881              287409
