# %%
from IPython.display import Image
from src.public_portal import *

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
url = 'http://apis.data.go.kr/9710000/ProceedingInfoService/getLatestConInfoList'
params = {
    'class_code': '1',
}
df = get_df_from_url(url, params)
df
# Out:
#   commName  confDate conferNum daeDisp degreeNum                                                                              hwpLink                                                                              pdfLink sesNum                                                            summary                                                                      vodLink
# 0  국회본회의    20190405  049083    제20대국회  제10차      http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049083&fileType=hwp  http://likms.assembly.go.kr/record/mhs-10-040-0040.do?conferNum=049083&fileType=PDF  제367회  http://likms.assembly.go.kr/record/mhs-10-030.do?conferNum=049083  http://w3.assembly.go.kr/jsp/vod/vod.do?cmd=vod&mc=10&ct1=20&ct2=367&ct3=10
# ...

# %%
url = 'http://apis.data.go.kr/9710000/ProceedingInfoService/getConCommitSearch'
params = {
#     's_dae_num': '20',
#     'class_code': '2',
    'comm_gb': '1',
}
df = get_df_from_url(url, params)
df
# Out:
#    commCode                                    commName daeNum   ord
# 0   TU       감사원장(황찬현)임명동의에관한인사청문특별위원회                   19     9999
# 1   JW       개인정보대량유출관련실태조사및재발방지를위한국정조사(정무위원회)           19     9999
# 2   JS       공공의료정상화를위한국정조사특별위원회                         19     9999
# 3   A8       공무원연금개혁특별위원회                                19     9999
# 4   AD       공적연금강화와노후빈곤해소를위한특별위원회                       19     999
# 5   QD       교육과학기술위원회                                   19     601
# 6   QE       교육문화체육관광위원회                                 19     600
# 7   JT       국가정보원댓글의혹사건등의진상규명을위한국정조사특별위원회               19     9999
# 8   JV       국가정보원등국가기관의정치적중립성강화를위한제도개선특별위원회             19     9999
# 9   AG       국무총리(이완구)임명동의에관한인사청문특별위원회                   19     9999
# 10  AA       국무총리(황교안)임명동의에관한인사청문특별위원회                   19     999
# 11  JL       국무총리실산하민간인불법사찰및증거인멸사건의진상규명을위한국정조사특별위원회      19     9999
# 12  T4       국무총리후보자(정홍원)에관한인사청문특별위원회                    19     9999
# ...

# %%
image = '/home/jake/Dev/popong/crawlers/rokps/images/2560.jpg'
Image(filename=image)
