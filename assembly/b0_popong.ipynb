# %%
from IPython.display import Image
import pandas as pd

# %%
dir_popong = '/home/jake/Dev/popong/crawlers/'
dir_assembly = dir_popong + 'national_assembly/'

file_assembly = 'assembly.csv'

path_assembly = dir_assembly + file_assembly

# %%
assem = pd.read_csv(path_assembly)
assem.head()
# Out:
#   name_kr name_cn        name_en       birth   party         district  \
# 0     강길부     姜吉夫   KANG GHILBOO  1942-06-05     무소속           울산 울주군
# 1     강병원     姜炳遠  KANG BYUNGWON  1971-07-09  더불어민주당          서울 은평구을
# 2     강석진     姜錫振   KANG SEOKJIN  1959-12-07   자유한국당  경남 산청군함양군거창군합천군
# 3     강석호     姜碩鎬    KANG SEOKHO  1955-12-03   자유한국당  경북 영양군영덕군봉화군울진군
# 4     강창일     姜昌一   KANG CHANGIL  1952-01-28  더불어민주당          제주 제주시갑
#
#            committee                 when_elected    off_phone  \
# 0    산업통상자원중소벤처기업위원회  4선( 17대 , 18대 , 19대 , 20대 )  02-788-2708
# 1  국회운영위원회 , 기획재정위원회                    초선( 20대 )  02-784-1422
# 2      농림축산식품해양수산위원회                    초선( 20대 )  02-784-1460
# 3            외교통일위원회        3선( 18대 , 19대 , 20대 )  02-784-2376
# 4            행정안전위원회  4선( 17대 , 18대 , 19대 , 20대 )  02-784-6084
#
#                 homepage                    email      aides   pr_secrs  \
# 0                    NaN  uljukang@assembly.go.kr  윤지현 , 정재원  이수철 , 차상윤
# ...

# %%
image = '/home/jake/Dev/popong/crawlers/rokps/images/2560.jpg'
Image(filename=image)
