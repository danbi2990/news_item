# %%
import pandas as pd

# %%
dir_item = '/home/jake/Documents/News_Item/'
dir_proj = dir_item + 'Consumer_Relief/'
dir_tableau = dir_proj + 'tableau_data/'

# %%
relief = pd.read_csv(dir_proj + 'consumer_relief_2019_1.csv', sep=',', encoding='euckr')
relief.head()
# Out:
#          사건번호             접수일(년월일)  성별       연령대     지역        물품소분류     판매유형  \
# 0  2019008215  2019-02-21 00:00:00  남성  50 - 59세  서울특별시          봉지면     일반판매
# 1  2019013119  2019-03-26 00:00:00  여성  50 - 59세  서울특별시  기타곡류·곡류가공식품  국내온라인거래
# 2  2019004137  2019-01-23 00:00:00  남성  20 - 29세   경상북도            게    모바일거래
# 3  2019004836  2019-01-28 00:00:00  남성  60 - 64세    경기도           어묵  국내온라인거래
# 4  2019006798  2019-02-12 00:00:00  여성  30 - 39세    경기도  기타육류·육류가공식품  국내온라인거래
#
#            청구이유
# 0     안전(제품/시설)
# 1   계약해제.해지/위약금
# 2         표시.광고
# 3  계약불이행(불완전이행)
# 4   계약해제.해지/위약금

# %%
relief.loc[relief['물품소분류'].str.contains('교육')].head()
# Out:
#            사건번호             접수일(년월일)  성별       연령대     지역     물품소분류    판매유형  \
# 971  2019001105  2019-01-08 00:00:00  남성  30 - 39세  서울특별시   기타교육서비스    일반판매
# 972  2019007502  2019-02-18 00:00:00  여성  20 - 29세    경기도   기타교육서비스    일반판매
# 973  2019008028  2019-02-20 00:00:00  남성  40 - 49세    강원도   기타교육서비스      기타
# 988  2019000381  2019-01-02 00:00:00  여성  30 - 39세  울산광역시  인터넷교육서비스    방문판매
# 989  2019000562  2019-01-03 00:00:00  여성  20 - 29세    강원도  인터넷교육서비스  기타통신판매
#
#             청구이유
# 971  계약해제.해지/위약금
# 972  계약해제.해지/위약금
# 973         청약철회
# 988  계약해제.해지/위약금
# 989  계약해제.해지/위약금

# %%
relief['물품소분류'].value_counts()
# Out:
# 투자자문(컨설팅)        659
# 헬스장·휘트니스센터       492
# 점퍼·재킷류           285
# 국외여행             252
# 항공여객운송서비스        250
# 이동전화서비스          248
# 양복(서양식 의복)세탁     232
# TV               180
# 운동화              152
# 코트               148
# 포장이사운송서비스        130
# 스마트폰             127
# 정수기대여(렌트)        110
# 인터넷교육서비스         104
# 기타의류·섬유           97
# 건강(암·기타질병)보험      91
# 소파                88
# 미분류대여(렌트)         87
# 숙녀화(구두·부츠 등)      83
# 택배화물운송서비스         82
# 시계                81
# 상조서비스             79
# 초고속인터넷            78
# 원피스               78
# 인터넷정보이용서비스        73
# 스포츠시설이용           72
# 기타미분류물품           72
# 기타사설강습서비스         72
# 호텔                71
# 캐주얼바지             71
#                 ...
# 토스터기               1
# 민박기타               1
# 항공기                1
# 마사지류               1
# CD플레이어             1
# 와이퍼                1
# 전자사전               1
# 기타과일·과일가공식품        1
# 헤어크림               1
# 악기용품               1
# 카오디오·스테레오          1
# 이용서비스              1
# ...

# %%
relief.loc[relief['물품소분류'].str.contains('헬스')].head(5)
# Out:
#            사건번호             접수일(년월일)  성별       연령대     지역       물품소분류  \
# 837  2019008608  2019-02-25 00:00:00  남성  50 - 59세    경기도  헬스장·휘트니스센터
# 838  2019000300  2019-01-02 00:00:00  여성  30 - 39세  서울특별시  헬스장·휘트니스센터
# 839  2019000062  2019-01-02 00:00:00  여성  40 - 49세  울산광역시  헬스장·휘트니스센터
# 840  2019000394  2019-01-02 00:00:00  여성  40 - 49세  서울특별시  헬스장·휘트니스센터
# 841  2019000629  2019-01-03 00:00:00  남성  30 - 39세  서울특별시  헬스장·휘트니스센터
#
#         판매유형         청구이유
# 837  국내온라인거래         부당행위
# 838     일반판매  계약해제.해지/위약금
# 839     일반판매  계약해제.해지/위약금
# 840     일반판매  계약해제.해지/위약금
# 841     일반판매  계약해제.해지/위약금

# %%
relief.loc[relief['물품소분류']=='투자자문(컨설팅)'].head(20)
# Out:
#             사건번호             접수일(년월일)  성별       연령대     지역      물품소분류    판매유형  \
# 1062  2019001795  2019-01-10 00:00:00  남성  30 - 39세   경상북도  투자자문(컨설팅)  전화권유판매
# 1063  2019002286  2019-01-14 00:00:00  여성  65 - 69세    경기도  투자자문(컨설팅)   모바일거래
# 1064  2019003045  2019-01-17 00:00:00  남성  50 - 59세   전라북도  투자자문(컨설팅)  전화권유판매
# 1065  2019004898  2019-01-28 00:00:00  남성  50 - 59세    경기도  투자자문(컨설팅)  전화권유판매
# 1066  2019006582  2019-02-11 00:00:00  여성  50 - 59세  서울특별시  투자자문(컨설팅)  전화권유판매
# 1067  2019006623  2019-02-11 00:00:00  여성  50 - 59세    경기도  투자자문(컨설팅)  전화권유판매
# 1068  2019007139  2019-02-14 00:00:00  남성  50 - 59세  서울특별시  투자자문(컨설팅)  전화권유판매
# 1069  2019007767  2019-02-19 00:00:00  남성  40 - 49세  부산광역시  투자자문(컨설팅)  전화권유판매
# 1070  2019008228  2019-02-21 00:00:00  남성  40 - 49세    경기도  투자자문(컨설팅)  전화권유판매
# 1071  2019008365  2019-02-22 00:00:00  남성  50 - 59세  부산광역시  투자자문(컨설팅)  전화권유판매
# 1072  2019008777  2019-02-26 00:00:00  여성  50 - 59세  서울특별시  투자자문(컨설팅)  전화권유판매
# ...
