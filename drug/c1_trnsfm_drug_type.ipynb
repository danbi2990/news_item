# %%
import pandas as pd

# %% [markdown]
# # data

# %%
data = '''\
종류	양	기간
헤로인(g)	0	201104
생아편(g)	0	201104
코카인(g)	2100	201104
필로폰(g)	11,494	201104
MDMA(정)	1	201104
LSD(정)	0	201104
YABA(정)	0	201104
향정_기타	3,799	201104
대마초(g)	71,333	201104
해쉬쉬(g)	33	201104
헤로인(g)	0	201105
생아편(g)	0	201105
코카인(g)	2,100	201105
필로폰(g)	14,904	201105
MDMA(정)	1	201105
LSD(정)	0	201105
YABA(정)	0	201105
향정_기타	4,021	201105
대마초(g)	72,731	201105
해쉬쉬(g)	33	201105
헤로인(g)	0	201106
생아편(g)	0	201106
코카인(g)	2,100	201106
필로폰(g)	17,798	201106
MDMA(정)	1	201106
LSD(정)	0	201106
YABA(정)	0	201106
향정_기타	4,765	201106
대마초(g)	72,883	201106
해쉬쉬(g)	33	201106
헤로인(g)	0	201107
생아편(g)	0	201107
코카인(g)	2,100	201107
필로폰(g)	17,897	201107
MDMA(정)	1	201107
LSD(정)	0	201107
YABA(정)	0	201107
향정_기타	6,616	201107
대마초(g)	73,930	201107
해쉬쉬(g)	33	201107
헤로인(g)	0	201108
생아편(g)	0	201108
코카인(g)	2,102	201108
필로폰(g)	18,096	201108
MDMA(정)	1	201108
LSD(정)		201108
YABA(정)	0	201108
향정_기타	6,815	201108
대마초(g)	75,163	201108
해쉬쉬(g)	33	201108
헤로인(g)	0	201109
생아편(g)	0	201109
코카인(g)	2,102	201109
필로폰(g)	20,166	201109
MDMA(정)	1	201109
LSD(정)		201109
YABA(정)	0	201109
향정_기타	7,789	201109
대마초(g)	75,240	201109
해쉬쉬(g)	33	201109
헤로인(g)	0	201110
생아편(g)	0	201110
코카인(g)	2,107	201110
필로폰(g)	20,797	201110
MDMA(정)	1	201110
LSD(정)		201110
YABA(정)	0	201110
향정_기타	8,751	201110
대마초(g)	77,362	201110
해쉬쉬(g)	60	201110
헤로인(g)	0	201111
생아편(g)	0	201111
코카인(g)	2,107	201111
필로폰(g)	21,099	201111
MDMA(정)	1	201111
LSD(정)		201111
YABA(정)	0	201111
향정_기타	9,848	201111
대마초(g)	78,394	201111
해쉬쉬(g)	60	201111
헤로인(g)	0	201112
생아편(g)	0	201112
코카인(g)	2,153	201112
필로폰(g)	23,466	201112
MDMA(정)	562	201112
LSD(정)		201112
YABA(정)	5	201112
향정_기타	10,203	201112
대마초(g)	83,559	201112
해쉬쉬(g)	60	201112
헤로인(g)	4	201201
생아편(g)		201201
코카인(g)		201201
필로폰(g)	428	201201
MDMA(정)	5	201201
LSD(정)		201201
YABA(정)		201201
향정_기타	760	201201
대마초(g)	792	201201
해쉬쉬(g)		201201
헤로인(g)	4	201202
생아편(g)		201202
코카인(g)	61	201202
필로폰(g)	789	201202
MDMA(정)	234	201202
LSD(정)		201202
YABA(정)		201202
향정_기타	2,818	201202
대마초(g)	11,632	201202
해쉬쉬(g)		201202
헤로인(g)	4	201203
생아편(g)		201203
코카인(g)	61	201203
필로폰(g)	2,951	201203
MDMA(정)	407	201203
LSD(정)		201203
YABA(정)		201203
향정_기타	4,065	201203
대마초(g)	12,660	201203
해쉬쉬(g)	0	201203
헤로인(g)	4	201204
생아편(g)		201204
코카인(g)	61	201204
필로폰(g)	3,245	201204
MDMA(정)	2,326	201204
LSD(정)		201204
YABA(정)		201204
향정_기타	2,920	201204
대마초(g)	13,491	201204
해쉬쉬(g)	0	201204
헤로인(g)	4	201206
생아편(g)		201206
코카인(g)	64	201206
필로폰(g)	4,298	201206
MDMA(정)	2,331	201206
LSD(정)		201206
YABA(정)		201206
향정_기타	6,055	201206
대마초(g)	14,063	201206
해쉬쉬(g)	24	201206
헤로인(g)	4	201207
생아편(g)		201207
코카인(g)	64	201207
필로폰(g)	6,101	201207
MDMA(정)	2,334	201207
LSD(정)	34	201207
YABA(정)		201207
향정_기타	4,837	201207
대마초(g)	14,232	201207
해쉬쉬(g)	285	201207
헤로인(g)	4	201208
생아편(g)		201208
코카인(g)	64	201208
필로폰(g)	11,172	201208
MDMA(정)	2,334	201208
LSD(정)	34	201208
YABA(정)		201208
JWH및유사체	3,891	201208
향정_기타	5,198	201208
대마초(g)	15,575	201208
해쉬쉬(g)	285	201208
헤로인(g)	4	201209
생아편(g)		201209
코카인(g)	64	201209
필로폰(g)	12,474	201209
MDMA(정)	2,334	201209
LSD(정)	34	201209
YABA(정)	402	201209
JWH및유사체	3,891	201209
향정_기타	5,310	201209
대마초(g)	16,575	201209
해쉬쉬(g)	286	201209
헤로인(g)	4	201210
생아편(g)		201210
코카인(g)	64	201210
필로폰(g)	18,196	201210
MDMA(정)	2,334	201210
LSD(정)	34	201210
YABA(정)	402	201210
JWH및유사체	4,013	201210
향정_기타	7,229	201210
대마초(g)	17,081	201210
해쉬쉬(g)	328	201210
헤로인(g)	4	201211
생아편(g)		201211
코카인(g)	64	201211
필로폰(g)	20,167	201211
MDMA(정)	2,344	201211
LSD(정)	34	201211
YABA(정)	402	201211
JWH및유사체	4,455	201211
향정_기타	7,229	201211
대마초(g)	19,800	201211
해쉬쉬(g)	334	201211
헤로인(g)	4	201212
생아편(g)		201212
코카인(g)	64	201212
필로폰(g)	20,716	201212
MDMA(정)	2,344	201212
LSD(정)	34	201212
YABA(정)	402	201212
JWH및유사체	4,455	201212
향정_기타	7,229	201212
대마초(g)	21,722	201212
해쉬쉬(g)	334	201212
헤로인(g)	0	201301
생아편(g)		201301
코카인(g)	10	201301
필로폰(g)	2,393	201301
MDMA(정)	21	201301
LSD(정)		201301
YABA(정)		201301
JWH및유사체	602	201301
향정_기타	596	201301
대마초(g)	498	201301
해쉬쉬(g)	20	201301
헤로인(g)	0	201302
생아편(g)		201302
코카인(g)	10	201302
필로폰(g)	2,728	201302
MDMA(정)	22	201302
LSD(정)		201302
YABA(정)	1,569	201302
JWH및유사체	623	201302
향정_기타	705	201302
대마초(g)	1,805	201302
해쉬쉬(g)	20	201302
헤로인(g)	0	201303
생아편(g)		201303
코카인(g)	10	201303
필로폰(g)	6,230	201303
MDMA(정)	22	201303
LSD(정)		201303
YABA(정)	471	201303
JWH및유사체	748	201303
향정_기타	949	201303
대마초(g)	2,208	201303
해쉬쉬(g)	22	201303
헤로인(g)	0	201304
생아편(g)		201304
코카인(g)	12	201304
필로폰(g)	14,602	201304
MDMA(정)	155	201304
YABA(정)	471	201304
JWH및유사체	814	201304
대마초(g)	3,186	201304
해쉬쉬(g)	22	201304
헤로인(g)	0	201305
생아편(g)		201305
코카인(g)	12	201305
필로폰(g)	21,259	201305
MDMA(정)	158	201305
YABA(정)	471	201305
JWH및유사체	814	201305
대마초(g)	7,208	201305
해쉬쉬(g)	23	201305
헤로인(g)	0	201306
생아편(g)		201306
코카인(g)	14	201306
필로폰(g)	21,611	201306
MDMA(정)	158	201306
YABA(정)	471	201306
JWH및유사체	933	201306
대마초(g)	7,370	201306
해쉬쉬(g)	23	201306
헤로인(g)	0	201307
생아편(g)		201307
코카인(g)	14	201307
필로폰(g)	22,627	201307
MDMA(정)	162	201307
YABA(정)	471	201307
JWH및유사체	933	201307
대마초(g)	9,382	201307
해쉬쉬(g)	39	201307
헤로인(g)	0	201308
생아편(g)		201308
코카인(g)	14	201308
필로폰(g)	24,222	201308
MDMA(정)	162	201308
YABA(정)	471	201308
JWH및유사체	957	201308
대마초(g)	9,457	201308
해쉬쉬(g)	39	201308
헤로인(g)	0	201309
생아편(g)		201309
코카인(g)	14	201309
필로폰(g)	24,401	201309
MDMA(정)	261	201309
YABA(정)	529	201309
JWH및유사체	963	201309
대마초(g)	9,656	201309
해쉬쉬(g)	44	201309
헤로인(g)	1	201311
생아편(g)	0	201311
코카인(g)	1,202	201311
필로폰(g)	30,077	201311
MDMA(정)	287	201311
YABA(정)	1,272	201311
JWH및유사체	1,128	201311
대마초(g)	22,963	201311
해쉬쉬(g)	65	201311
헤로인(g)	1	201312
생아편(g)	0	201312
코카인(g)	1,202	201312
필로폰(g)	37,689	201312
MDMA(정)	407	201312
YABA(정)	1,319	201312
JWH및유사체	1,107	201312
대마초(g)	23,397	201312
해쉬쉬(g)	66	201312
헤로인(g)	1	201401
생아편(g)	110	201401
코카인(g)	9	201401
필로폰(g)	836	201401
MDMA(정)	6	201401
LSD(정)	0	201401
YABA(정)	0	201401
JWH및유사체	0	201401
향정_기타	596	201401
대마초(g)	5,134	201401
해쉬쉬(g)	0	201401
헤로인(g)	1	201402
생아편(g)	110	201402
코카인(g)	11	201402
필로폰(g)	5,183	201402
MDMA(정)	132	201402
LSD(정)	0	201402
YABA(정)	28	201402
JWH및유사체	43	201402
향정_기타	596	201402
대마초(g)	5,515	201402
해쉬쉬(g)	0	201402
헤로인(g)	1	201403
생아편(g)	110	201403
코카인(g)	11	201403
필로폰(g)	5,450	201403
MDMA(정)	140	201403
LSD(정)	0	201403
YABA(정)	62	201403
JWH및유사체	43	201403
향정_기타	3,031	201403
대마초(g)	5,759	201403
해쉬쉬(g)	0	201403
헤로인(g)	1	201404
생아편(g)	110	201404
코카인(g)	11	201404
필로폰(g)	26,362	201404
MDMA(정)	147	201404
YABA(정)	62	201404
JWH및유사체	48	201404
향정_기타	3,502	201404
대마초(g)	11,359	201404
해쉬쉬(g)	11	201404
헤로인(g)	1	201405
생아편(g)	110	201405
코카인(g)	11	201405
필로폰(g)	26,726	201405
MDMA(정)	151	201405
YABA(정)	85	201405
JWH및유사체	48	201405
향정_기타	3,130	201405
대마초(g)	12,656	201405
해쉬쉬(g)	15	201405
헤로인(g)	1	201406
생아편(g)	110	201406
코카인(g)	11	201406
필로폰(g)	33,063	201406
MDMA(정)	151	201406
YABA(정)	0	201406
JWH및유사체	48	201406
향정_기타	4,855	201406
대마초(g)	13,133	201406
해쉬쉬(g)	15	201406
헤로인(g)	1	201407
생아편(g)	110	201407
코카인(g)	11	201407
필로폰(g)	33,429	201407
MDMA(정)	151	201407
YABA(정)	85	201407
JWH및유사체	48	201407
향정_기타	5,027	201407
대마초(g)	13,584	201407
해쉬쉬(g)	328	201407
헤로인(g)	1	201408
생아편(g)	110	201408
코카인(g)	11	201408
필로폰(g)	33,734	201408
MDMA(정)	151	201408
YABA(정)	85	201408
JWH및유사체	48	201408
대마초(g)	14,039	201408
해쉬쉬(g)	328	201408
헤로인(g)	1	201409
생아편(g)	110	201409
코카인(g)	11	201409
필로폰(g)	64,776	201409
MDMA(정)	0	201409
YABA(정)	0	201409
JWH및유사체	0	201409
대마초(g)	27	201409
해쉬쉬(g)	39,966	201409
헤로인(g)	1	201410
생아편(g)	110	201410
코카인(g)	11	201410
양귀비(주)	65,023	201410
모르핀(mg)	0	201410
코데인(g)	0	201410
복방감초편(g)	0	201410
마약_기타	27	201410
필로폰(g)	45,650	201410
MDMA(g)	204	201410
LSD(g)	1	201410
YABA(g)	315	201410
JWH및유사체	49	201410
향정_기타	6,860	201410
대마초(g)	17,335	201410
해쉬쉬(g)	334	201410
대마(주)	3,968	201410
대마종자(g)	4,389	201410
헤로인(g)	1	201411
생아편(g)	110	201411
코카인(g)	11	201411
양귀비(주)	65,023	201411
모르핀(mg)	0	201411
코데인(g)	0	201411
복방감초편(g)	0	201411
마약_기타	93	201411
필로폰(g)	47,501	201411
MDMA(g)	204	201411
LSD(g)	1	201411
YABA(g)	315	201411
JWH및유사체	49	201411
향정_기타	7,218	201411
대마초(g)	18,448	201411
해쉬쉬(g)	334	201411
대마(주)	5,088	201411
대마종자(g)	4,391	201411
헤로인(g)	1	201412
생아편(g)	110	201412
코카인(g)	11	201412
양귀비(주)	65,023	201412
모르핀(mg)	0	201412
코데인(g)	0	201412
복방감초편(g)	0	201412
마약_기타	93	201412
필로폰(g)	47,680	201412
MDMA(g)	216	201412
LSD(g)	8	201412
YABA(g)	930	201412
JWH및유사체	49	201412
향정_기타	15,017	201412
대마초(g)	23,315	201412
해쉬쉬(g)	334	201412
대마(주)	5,088	201412
대마종자(g)	4,391	201412
헤로인(g)	4	201205
생아편(g)	0	201205
코카인(g)	64	201205
필로폰(g)	3,739	201205
MDMA(정)	2,331	201205
LSD(정)		201205
YABA(정)		201205
향정_기타	5,575	201205
대마초(g)	13,823	201205
해쉬쉬(g)	17	201205
'''

# %% [markdown]
# # df

# %%
from io import StringIO
io = StringIO(data)
df = pd.read_csv(io, sep='\t')
df.head()
# Out:
#         종류       양      기간
# 0   헤로인(g)       0  201104
# 1   생아편(g)       0  201104
# 2   코카인(g)    2100  201104
# 3   필로폰(g)  11,494  201104
# 4  MDMA(정)       1  201104

# %%
'''
헤로인(g)*	생아편(g)*	코카인(g)*	양귀비㈜	모르핀(mg)	코데인(g)	복방감초편(g)	기타(마약)	필로폰(g)*	MDMA(g)*	LSD(g)	YABA(g)*	JWH 및 유사체*	기타(향정)	대마초(g)*	해시시(g)*	대마㈜	대마종자(g)	기타(대마)
'''

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

df2 = df.pivot(columns='종류', index='기간', values='양')
print(df2.columns)
cols = ['헤로인(g)', '생아편(g)', '코카인(g)', '양귀비(주)', '모르핀(mg)', '코데인(g)', '복방감초편(g)', '마약_기타', '필로폰(g)', 'MDMA(g)', 'MDMA(정)', 'LSD(g)', 'LSD(정)', 'YABA(g)', 'YABA(정)', 'JWH및유사체', '향정_기타', '대마초(g)', '해쉬쉬(g)', '대마(주)', '대마종자(g)']
df2.loc[::, cols].sort_values('기간', ascending=False)
# Out:
# Index(['JWH및유사체', 'LSD(g)', 'LSD(정)', 'MDMA(g)', 'MDMA(정)', 'YABA(g)',
#        'YABA(정)', '대마(주)', '대마종자(g)', '대마초(g)', '마약_기타', '모르핀(mg)', '복방감초편(g)',
#        '생아편(g)', '양귀비(주)', '코데인(g)', '코카인(g)', '필로폰(g)', '해쉬쉬(g)', '향정_기타',
#        '헤로인(g)'],
#       dtype='object', name='종류')
# 종류     헤로인(g) 생아편(g) 코카인(g)  양귀비(주) 모르핀(mg) 코데인(g) 복방감초편(g) 마약_기타  필로폰(g)  \
# 기간
# 201412  1      110    11     65,023  0       0      0        93    47,680
# 201411  1      110    11     65,023  0       0      0        93    47,501
# 201410  1      110    11     65,023  0       0      0        27    45,650
# 201409  1      110    11     NaN     NaN     NaN    NaN      NaN   64,776
# 201408  1      110    11     NaN     NaN     NaN    NaN      NaN   33,734
# 201407  1      110    11     NaN     NaN     NaN    NaN      NaN   33,429
# 201406  1      110    11     NaN     NaN     NaN    NaN      NaN   33,063
# 201405  1      110    11     NaN     NaN     NaN    NaN      NaN   26,726
# ...
