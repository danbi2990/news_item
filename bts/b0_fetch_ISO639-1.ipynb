# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

import src.mongos as mg

# %%
url = 'https://en.wikipedia.org/wiki/List_of_ISO_639-1_codes'

r = requests.get(url)
dfs = pd.read_html(r.text); dfs
# Out:
# [    0                                                  1
#  0 NaN  This article needs additional citations for ve...,
#       Unnamed: 0      Language family        ISO language name  \
#  0           NaN  Northwest Caucasian                Abkhazian
#  1           NaN         Afro-Asiatic                     Afar
#  2           NaN        Indo-European                Afrikaans
#  3           NaN          Niger–Congo                     Akan
#  4           NaN        Indo-European                 Albanian
#  5           NaN         Afro-Asiatic                  Amharic
#  6           NaN         Afro-Asiatic                   Arabic
#  7           NaN        Indo-European                Aragonese
#  8           NaN        Indo-European                 Armenian
#  9           NaN        Indo-European                 Assamese
#  10          NaN  Northeast Caucasian                   Avaric
#  11          NaN        Indo-European                  Avestan
# ...

# %%
df = dfs[1]
df.drop(df.columns[0], axis=1, inplace=True); df
# Out:
#          Language family        ISO language name     Native name (endonym)  \
# 0    Northwest Caucasian                Abkhazian      аҧсуа бызшәа, аҧсшәа
# 1           Afro-Asiatic                     Afar                    Afaraf
# 2          Indo-European                Afrikaans                 Afrikaans
# 3            Niger–Congo                     Akan                      Akan
# 4          Indo-European                 Albanian                     Shqip
# 5           Afro-Asiatic                  Amharic                      አማርኛ
# 6           Afro-Asiatic                   Arabic                   العربية
# 7          Indo-European                Aragonese                  aragonés
# 8          Indo-European                 Armenian                   Հայերեն
# 9          Indo-European                 Assamese                   অসমীয়া
# 10   Northeast Caucasian                   Avaric  авар мацӀ, магӀарул мацӀ
# ...

# %%
# mg.to_mongo(df, 'youtube_comment', 'languages')
# Out:
# Inserted rows: 184
