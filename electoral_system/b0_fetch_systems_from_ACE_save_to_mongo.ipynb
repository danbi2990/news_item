# %%
import re

import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

from src.common import *
import src.mongos as mg

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Country List

# %% [markdown]
# ### Fetch

# %%
def fetch_countries():
    url = 'http://aceproject.org/regions-en/countries-and-territories/KR/default?set_language=en'
    r = requests.get(url)
    soup = bs(r.text)
    options = soup.select('select.cd-country-dropdown > option')
    return options


options = fetch_countries()

# %% [markdown]
# ### Test

# %%
def test_countries(options):
    tmp = options[0]['value']
    re.search(r'ries/(\w\w)/def', tmp).group(1)
    return options[0].text.strip()


# test_countries(options)

# %% [markdown]
# ### Parse

# %%
def parse_countries(options):
    urls, names, codes = [], [], []

    for o in options:
        url = o.get('value', '')
        urls.append(url)

        obj = re.search(r'ries/(\w\w)/def', url)
        if obj:
            code = obj.group(1)
        else:
            code = ''
        codes.append(code)

        name = o.text.strip()
        names.append(name)
    return urls, names, codes


# urls, names, codes = parse_countries(options)
# for x in [urls, names, codes]:
#     print(len(x))

# %% [markdown]
# ## All Countries

# %% [markdown]
# ### Test

# %%
def get_qna(soup):
    td = soup.find('td', attrs={'valign':'top', 'width':'45%'})
    list_raw_qna = str(td).split('<br/>')[1:-2]

    list_qna = []
    for qna in list_raw_qna:
        soup_qna = bs(qna)
        try:
            question = soup_qna.select('.cdquestion')[0].text.strip()
        except IndexError as e:
#             print(soup_qna)
            continue
        answer = ', '.join([x.text.strip() for x in soup_qna.select('.cdanswer')])
        list_qna.append((question, answer))

    return list_qna


def dictionize_qna(qna, name, code):
    dict_qna = dict(qna)
    dict_qna['Country'] = name
    dict_qna['Code'] = code
    return dict_qna


# qna = get_qna(soup)
# dictionize_qna(qna, 'a', 'b')

# qna

# %% [markdown]
# ### Fetch all countries

# %%
def fetch_all_countries(urls, names, codes):
    if (len(urls) != len(names)) or (len(urls) != len(codes)):
        raise ValueError("Lengths of urls, names, codes are different.")
    
    all_qna = []

    for i, u in enumerate(urls):
        r = requests.get(u)
        soup = bs(r.text)
        list_qna = get_qna(soup)
        name = names[i]
        code = codes[i]
#         if code == 'PM':  # maybe required?
#             continue
        dict_qna = dictionize_qna(list_qna, name, code)
        all_qna.append(dict_qna)
    
    return all_qna

# idx = 10
# all_qna = fetch_all_countries(urls[:idx], names[:idx], codes[:idx])
all_qna = fetch_all_countries(urls, names, codes)

all_qna
# Out:
# [{'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Single Non-Transferable Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Other, No information available',
#   'Country': 'Afghanistan',
#   'Code': 'AF'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Not applicable',
#   'Country': 'Albania',
#   'Code': 'AL'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Algeria',
#   'Code': 'DZ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'American Samoa',
#   'Code': 'AS'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Students, Other',
#   'Country': 'Andorra',
#   'Code': 'AD'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Members of the armed forces, Students, Diplomatic staff, Other',
#   'Country': 'Angola',
#   'Code': 'AO'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Anguilla',
#   'Code': 'AI'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Other',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Other, No information available',
#   'Country': 'Antigua and Barbuda',
#   'Code': 'AG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Argentina',
#   'Code': 'AR'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Diplomatic staff, Other',
#   'Country': 'Armenia',
#   'Code': 'AM'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Aruba',
#   'Code': 'AW'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Alternative Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Australia',
#   'Code': 'AU'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation)',
#   'Country': 'Austria',
#   'Code': 'AT'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Diplomatic staff',
#   'Country': 'Azerbaijan',
#   'Code': 'AZ'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Bahamas',
#   'Code': 'BS'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '20',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation)',
#   'Country': 'Bahrain',
#   'Code': 'BH'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Diplomatic staff',
#   'Country': 'Bangladesh',
#   'Code': 'BD'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Diplomatic staff',
#   'Country': 'Barbados',
#   'Code': 'BB'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Students, Diplomatic staff',
#   'Country': 'Belarus',
#   'Code': 'BY'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Belgium',
#   'Code': 'BE'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Belize',
#   'Code': 'BZ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Benin',
#   'Code': 'BJ'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Bermuda',
#   'Code': 'BM'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Bhutan',
#   'Code': 'BT'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Mixed Member Proportional',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Bolivia',
#   'Code': 'BO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff, Other',
#   'Country': 'Bosnia and Herzegovina',
#   'Code': 'BA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Botswana',
#   'Code': 'BW'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Brazil',
#   'Code': 'BR'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Not applicable',
#   'Voting age': 'Not applicable',
#   'Compulsory/voluntary voting': 'Not applicable',
#   'Electoral Management model': 'Not applicable',
#   'Voting outside the country is permitted for': 'Not applicable',
#   'Country': 'Brunei Darussalam',
#   'Code': 'BN'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Bulgaria',
#   'Code': 'BG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Other',
#   'Country': 'Burkina Faso',
#   'Code': 'BF'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Diplomatic staff',
#   'Country': 'Burma (Myanmar)',
#   'Code': 'MM'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Burundi',
#   'Code': 'BI'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Cambodia',
#   'Code': 'KH'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '20',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Cameroon',
#   'Code': 'CM'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Canada',
#   'Code': 'CA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Cape Verde',
#   'Code': 'CV'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Cayman Islands',
#   'Code': 'KY'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Central African Republic',
#   'Code': 'CF'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Chad',
#   'Code': 'TD'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Chile',
#   'Code': 'CL'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Other',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Not applicable',
#   'Electoral Management model': 'No information available',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'China',
#   'Code': 'CN'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': '',
#   'Electoral Management model': '',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Christmas Island',
#   'Code': 'CX'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': '',
#   'Electoral Management model': '',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Cocos (keeling) Islands',
#   'Code': 'CC'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Colombia',
#   'Code': 'CO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP), Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Comoros',
#   'Code': 'KM'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP), Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Diplomatic staff',
#   'Country': 'Congo (Brazzaville)',
#   'Code': 'CG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP), List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Congo (Kinshasa), Democratic Republic of the',
#   'Code': 'CD'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Cook Islands',
#   'Code': 'CK'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Costa Rica',
#   'Code': 'CR'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation)',
#   'Country': 'Croatia',
#   'Code': 'HR'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Cuba',
#   'Code': 'CU'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Cyprus',
#   'Code': 'CY'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Cyprus (North)',
#   'Code': 'CP'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Czech Republic',
#   'Code': 'CZ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': "Côte d'Ivoire",
#   'Code': 'CI'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Diplomatic staff, Other',
#   'Country': 'Denmark',
#   'Code': 'DK'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Mixed Member Proportional',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Djibouti',
#   'Code': 'DJ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Dominica',
#   'Code': 'DM'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Dominican Republic',
#   'Code': 'DO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP), Parallel (Segmented) (PR Lists and Majoritarian constituencies), List Proportional Representation',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Ecuador',
#   'Code': 'EC'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Egypt',
#   'Code': 'EG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Other',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'El Salvador',
#   'Code': 'SV'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Equatorial Guinea',
#   'Code': 'GQ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Diplomatic staff',
#   'Country': 'Eritrea',
#   'Code': 'ER'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Estonia',
#   'Code': 'EE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Ethiopia',
#   'Code': 'ET'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Block Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Students',
#   'Country': 'Falkland Islands (Malvinas)',
#   'Code': 'FK'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'No information available',
#   'Electoral Management model': '',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Faroe Islands',
#   'Code': 'FO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation)',
#   'Country': 'Fiji',
#   'Code': 'FJ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Finland',
#   'Code': 'FI'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'France',
#   'Code': 'FR'},
#  {'President': '',
#   'Electoral System (Chamber 1)': '',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'French Guiana',
#   'Code': 'GF'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'French Polynesia',
#   'Code': 'PF'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Gabon',
#   'Code': 'GA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Gambia',
#   'Code': 'GM'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Diplomatic staff',
#   'Country': 'Georgia',
#   'Code': 'GE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Mixed Member Proportional',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Germany',
#   'Code': 'DE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Students, Diplomatic staff',
#   'Country': 'Ghana',
#   'Code': 'GH'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Other',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Gibraltar',
#   'Code': 'GI'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Greece',
#   'Code': 'GR'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Diplomatic staff',
#   'Country': 'Greenland',
#   'Code': 'GL'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Grenada',
#   'Code': 'GD'},
#  {'President': '',
#   'Electoral System (Chamber 1)': '',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Guadeloupe',
#   'Code': 'GP'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students',
#   'Country': 'Guam',
#   'Code': 'GU'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Guatemala',
#   'Code': 'GT'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Block Vote',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': '',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Guernsey',
#   'Code': 'GG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Guinea',
#   'Code': 'GN'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Guinea-Bissau',
#   'Code': 'GW'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Diplomatic staff',
#   'Country': 'Guyana',
#   'Code': 'GY'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Haiti',
#   'Code': 'HT'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Not applicable',
#   'Voting age': 'Other (specify)',
#   'Compulsory/voluntary voting': 'No information available',
#   'Electoral Management model': 'Not applicable',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Holy See (Vatican City State)',
#   'Code': 'VA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law, Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Honduras',
#   'Code': 'HN'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Other',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'No information available',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Hong Kong',
#   'Code': 'HK'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Mixed Member Proportional',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Hungary',
#   'Code': 'HU'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Iceland',
#   'Code': 'IS'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Members of the armed forces, Diplomatic staff',
#   'Country': 'India',
#   'Code': 'IN'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '17',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Indonesia',
#   'Code': 'ID'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Iran, Islamic Republic of',
#   'Code': 'IR'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Iraq',
#   'Code': 'IQ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Single Transferable Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Ireland',
#   'Code': 'IE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Members of the armed forces, Diplomatic staff, Other',
#   'Country': 'Israel',
#   'Code': 'IL'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': 'Other (specify)',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Italy',
#   'Code': 'IT'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Jamaica',
#   'Code': 'JM'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Diplomatic staff, Other',
#   'Country': 'Japan',
#   'Code': 'JP'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Block Vote',
#   'Voting age': '16',
#   'Compulsory/voluntary voting': '',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Jersey',
#   'Code': 'JE'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies), List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Jordan',
#   'Code': 'JO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation, Other',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Kazakhstan',
#   'Code': 'KZ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Members of the armed forces, Diplomatic staff',
#   'Country': 'Kenya',
#   'Code': 'KE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Kiribati',
#   'Code': 'KI'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Alternative Vote',
#   'Voting age': '17',
#   'Compulsory/voluntary voting': 'No information available',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': "Korea, Democratic People's Republic of",
#   'Code': 'KP'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '19',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation)',
#   'Country': 'Korea, Republic of',
#   'Code': 'KR'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Block Vote',
#   'Voting age': '21',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Kuwait',
#   'Code': 'KW'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Kyrgyzstan',
#   'Code': 'KG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': "Lao People's Democratic Republic",
#   'Code': 'LA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Latvia',
#   'Code': 'LV'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Block Vote, List Proportional Representation',
#   'Voting age': '21',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Lebanon',
#   'Code': 'LB'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Mixed Member Proportional',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Diplomatic staff',
#   'Country': 'Lesotho',
#   'Code': 'LS'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Liberia',
#   'Code': 'LR'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Libyan Arab Jamahiriya',
#   'Code': 'LY'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Liechtenstein',
#   'Code': 'LI'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Lithuania',
#   'Code': 'LT'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Luxembourg',
#   'Code': 'LU'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': '',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Macau',
#   'Code': 'MO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff, Other',
#   'Country': 'Macedonia, the Former Yugoslav Republic of',
#   'Code': 'MK'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Madagascar',
#   'Code': 'MG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Malawi',
#   'Code': 'MW'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '21',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Malaysia',
#   'Code': 'MY'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
# ...
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Solomon Islands',
#   'Code': 'SB'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Not applicable',
#   'Voting age': 'No information available',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Somalia',
#   'Code': 'SO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff, Other',
#   'Country': 'South Africa',
#   'Code': 'ZA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Members of the armed forces, Other',
#   'Country': 'Spain',
#   'Code': 'ES'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Sri Lanka',
#   'Code': 'LK'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Sudan',
#   'Code': 'SD'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Suriname',
#   'Code': 'SR'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Swaziland',
#   'Code': 'SZ'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Sweden',
#   'Code': 'SE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Diplomatic staff',
#   'Country': 'Switzerland',
#   'Code': 'CH'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Block Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Syrian Arab Republic',
#   'Code': 'SY'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '20',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Taiwan',
#   'Code': 'TW'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens outside the country (including those on vacation)',
#   'Country': 'Tajikistan',
#   'Code': 'TJ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies), Other',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Tanzania, United Republic of',
#   'Code': 'TZ'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Thailand',
#   'Code': 'TH'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '17',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Timor-Leste',
#   'Code': 'TL'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Togo',
#   'Code': 'TG'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '',
#   'Compulsory/voluntary voting': '',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': '',
#   'Country': 'Tokelau',
#   'Code': 'TK'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '21',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Tonga',
#   'Code': 'TO'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Trinidad and Tobago',
#   'Code': 'TT'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Tunisia',
#   'Code': 'TN'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the electoral law',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Turkey',
#   'Code': 'TR'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'No information available',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Other',
#   'Country': 'Turkmenistan',
#   'Code': 'TM'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Not applicable',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Turks and Caicos Islands',
#   'Code': 'TC'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP), Block Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Tuvalu',
#   'Code': 'TV'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Uganda',
#   'Code': 'UG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'Ukraine',
#   'Code': 'UA'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Block Vote',
#   'Voting age': 'Other (specify)',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'United Arab Emirates',
#   'Code': 'AE'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Mixed',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff, Other',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Code': 'GB'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary, Other',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation), Members of the armed forces, Students, Diplomatic staff',
#   'Country': 'United States of America',
#   'Code': 'US'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'List Proportional Representation',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is compulsory and regulated in the constitution',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Uruguay',
#   'Code': 'UY'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Members of the armed forces',
#   'Country': 'Uzbekistan',
#   'Code': 'UZ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Single Non-Transferable Vote',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Vanuatu',
#   'Code': 'VU'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Parallel (Segmented) (PR Lists and Majoritarian constituencies)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Venezuela',
#   'Code': 'VE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Viet Nam',
#   'Code': 'VN'},
#  {'President': 'No',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Virgin Islands, British',
#   'Code': 'VG'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Governmental',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Virgin Islands, U.S.',
#   'Code': 'VI'},
#  {'President': 'No information available',
#   'Electoral System (Chamber 1)': 'Two-Round System',
#   'Voting age': 'No information available',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': '',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country',
#   'Country': 'Wallis and Futuna',
#   'Code': 'WF'},
#  {'President': 'No information available',
#   'Electoral System (Chamber 1)': 'No information available',
#   'Voting age': 'No information available',
#   'Compulsory/voluntary voting': 'No information available',
#   'Electoral Management model': '',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Western Sahara',
#   'Code': 'EH'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Citizens residing outside the country, Citizens outside the country (including those on vacation)',
#   'Country': 'Yemen',
#   'Code': 'YE'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'No information available',
#   'Country': 'Zambia',
#   'Code': 'ZM'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP), Mixed Member Proportional',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Outside the country voting is not permitted',
#   'Country': 'Zanzibar',
#   'Code': 'ZZ'},
#  {'President': 'Yes',
#   'Electoral System (Chamber 1)': 'Plurality (FPTP)',
#   'Voting age': '18',
#   'Compulsory/voluntary voting': 'Voting is voluntary',
#   'Electoral Management model': 'Independent',
#   'Voting outside the country is permitted for': 'Diplomatic staff, Other',
#   'Country': 'Zimbabwe',
#   'Code': 'ZW'}]

# %% [markdown]
# ### Make df

# %%
def make_systems(df):
    systems = pd.DataFrame(df)
    return systems


systems = make_systems(all_qna)
systems.head()

# %% [markdown]
# ### Save df

# %%
mg.to_mongo(systems, 'electoral_system', 'systems', dtype='df')
# Out:
# Inserted rows: 236
