# %%
import pandas as pd

from src.common import eprint
from src.common import SEOUL_GU
from src.common import get_df_from_excel

from src.club import dir_item, dir_proj, dir_tableau
from src.club import file_excels, file_tsvs
from src.club import export_big_three_gu

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
idx = 2
# export_big_three_gu(dir_proj, file_names[0])
export_big_three_gu(dir_proj, file_tsvs[idx])

# print(len(df))
# # df.head()
# idx_running = df['영업상태명']=='영업/정상'
# idx_arena = df['사업장명'].str.contains('아레나')
# df.loc[idx_arena].head()
# Out:
# /home/jake/.virtualenvs/workspace/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3215: DtypeWarning: Columns (39,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
# df = pd.read_csv(dir_proj + file_names[0], sep='\t')
print(df.shape)
df.head()
# Out:
# /home/jake/.virtualenvs/workspace/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (11,39,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (433240, 48)
#    번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0  1   일반음식점  07_24_04_P  3000000   3000000-101-1995-05094  19950720 NaN
# 1  2   일반음식점  07_24_04_P  3000000   3000000-101-1986-06559  19860820 NaN
# 2  3   일반음식점  07_24_04_P  3000000   3000000-101-1986-10482  19860821 NaN
# 3  4   일반음식점  07_24_04_P  3000000   3000000-101-1987-03681  19870107 NaN
# 4  5   일반음식점  07_24_04_P  3000000   3000000-101-1986-01204  19860825 NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  휴업종료일자  재개업일자       소재지전화  \
# 0  1         영업/정상  1         영업      NaN NaN     NaN     NaN     02 7656639
# 1  1         영업/정상  1         영업      NaN NaN     NaN     NaN     0207377981
# 2  1         영업/정상  1         영업      NaN NaN     NaN     NaN     02 7383713
# 3  1         영업/정상  1         영업      NaN NaN     NaN     NaN     0207471946
# 4  1         영업/정상  1         영업      NaN NaN     NaN     NaN     02 7376460
#
#   소재지면적   소재지우편번호                           소재지전체주소  \
# 0  NaN   110837.0  서울특별시 종로구 창신동 593-18번지
# 1  NaN   110051.0  서울특별시 종로구 도렴동 60-0번지 지하동 1-14호
# 2  NaN   110724.0  서울특별시 종로구 당주동 100번지 (세종빌딩 지하9호)
# 3  NaN   110460.0  서울특별시 종로구 연건동 190-30번지
# 4  NaN   110053.0  서울특별시 종로구 내자동 148-0번지 지상1층
#
#                                   도로명전체주소  도로명우편번호  사업장명          최종수정시점  \
# 0  서울특별시 종로구 창신6길 9-10 (창신동)               3096.0   만남호프  20010929000000
# 1  서울특별시 종로구 새문안로5길 37, 지하동 1-14호 (도렴동)    3173.0   수제비집  20080605113818
# 2  서울특별시 종로구 세종대로23길 54 (당주동,(세종빌딩 지하9호))  3173.0   아람    20080625103401
# 3  서울특별시 종로구 대학로 46 (연건동)                  3122.0   원조식당  20080421131924
# 4  서울특별시 종로구 사직로10길 9 (내자동,지상1층)           3169.0   향미정   20080528111210
#
#   데이터갱신구분                데이터갱신일자 업태구분명        좌표정보(X)        좌표정보(Y) 위생업태명  \
# 0  I       2018-08-31 23:59:59.0  경양식   200890.580078  452557.350891  경양식
# 1  I       2018-08-31 23:59:59.0  분식    197650.653737  452368.519289  분식
# 2  I       2018-08-31 23:59:59.0  분식    197573.030750  452175.335782  분식
# 3  I       2018-08-31 23:59:59.0  경양식   200134.205030  452551.558351  경양식
# 4  I       2018-08-31 23:59:59.0  분식    197319.375566  452580.545904  분식
#
#    남성종사자수  여성종사자수 영업장주변구분명 등급구분명 급수시설구분명  총종업원수  본사종업원수  공장사무직종업원수  공장판매직종업원수  \
# 0  0.0     0.0     기타       기타    상수도전용  NaN    NaN     NaN        NaN
# 1  1.0     1.0     기타       을     상수도전용  NaN    NaN     NaN        NaN
# 2  1.0     1.0     기타       을     NaN    NaN    NaN     NaN        NaN
# 3  1.0     3.0     기타       갑     상수도전용  NaN    NaN     NaN        NaN
# 4  1.0     1.0     기타       을     상수도전용  NaN    NaN     NaN        NaN
#
#    공장생산직종업원수 건물소유구분명  보증액  월세액 다중이용업소여부  시설총규모 전통업소지정번호 전통업소주된음식  홈페이지  자치구
# 0 NaN         NaN    NaN  NaN   N        22.00  NaN      NaN     NaN    종로구
# 1 NaN         NaN    NaN  NaN   N        15.30  NaN      NaN     NaN    종로구
# 2 NaN         NaN    NaN  NaN   N        21.35  NaN      NaN     NaN    종로구
# 3 NaN         NaN    NaN  NaN   N        56.21  NaN      NaN     NaN    종로구
# 4 NaN         NaN    NaN  NaN   N        16.95  NaN      NaN     NaN    종로구

# %%
import os
os.path.splitext(file_names[1])
# Out:
# ('store_190228_seoul_alcohol', '.tsv')
