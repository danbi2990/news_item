# %%
import json
import requests
import pandas as pd

from pprint import pprint

from src.club import dir_item, dir_proj, dir_tableau
from src.club import process_club
from src.club import cafeteria_club, liquor_club

import src.mongos as mg

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load 'club'

# %%
club = mg.read_mongo('club', 'club')

club = process_club(club)
print(len(club))
club.head()
# Out:
# /home/jake/Notebooks/src/club.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/jake/Notebooks/src/club.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/jake/Notebooks/src/club.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 78
#             abbrAddress                         address  \
# 0  서교동 356-1             서울특별시 마포구 서교동 356-1
# 1  서교동 407-3 2층          서울특별시 마포구 서교동 407-3 2층
# 2  서교동 361-18            서울특별시 마포구 서교동 361-18
# 3  서교동 362-4             서울특별시 마포구 서교동 362-4
# 4  서교동 408-16 DO빌딩 지하1층  서울특별시 마포구 서교동 408-16 DO빌딩 지하1층
#
#                                  bizhourInfo                   broadcastInfo  \
# 0  None                                       {'name': '힐링캠프', 'menu': None}
# 1  평일 19:30~24:00 명절휴무 | 주말 19:30~02:00 명절휴무  None
# 2  None                                       None
# 3  매일 19:30~04:00 금, 토요일 19:30~06:00 월요일 휴무.  None
# 4  None                                       None
#
#   carWash card      category                categoryPath              context  \
# 0               [스포츠,오락, 클럽]  [[221986, 221990, 230548]]  []
# 1               [스포츠,오락, 클럽]  [[221986, 221990, 230548]]  [공연, 재즈바, 칵테일, 데이트]
# 2               [스포츠,오락, 클럽]  [[221986, 221990, 230548]]  []
# 3               [스포츠,오락, 클럽]  [[221986, 221990, 230548]]  []
# 4               [스포츠,오락, 클럽]  [[221986, 221990, 230548]]  [공연, 보드카, 화려한]
#
#   coupon couponUrl couponUrlMobile  \
# 0  0      None      None
# 1  0      None      None
# 2  0      None      None
# 3  0      None      None
# 4  0      None      None
#
#                                                            description  \
# 0  서울특별시 마포구 서교동 위치, <b>클럽</b>, 파티, VIP테이블,라운지,룸 예약, 대관 정보 및 사진, 동영상 등
# 1  변함없이 연주되는 Jazz와 멈추지 않는 교감, 재즈를 느끼고 싶다면 EVANS.
# 2
# 3  양현석씨가 운영하는 <b>클럽</b>으로 정통 힙합 스타일의 음악을 틀어주는 곳.
# 4  매일 밤 공연을 볼 수 있는 <b>홍대 클럽</b>.
#
#                  display distance  \
# 0  베라                     6739.37
# 1  <b>클럽</b>에반스           6514.74
# 2  NB2                    6490.15
# 3  <b>클럽</b>nb <b>홍대</b>  6531.77
# 4  <b>클럽</b> 프리버드         6621.74
#
#                                                             entranceCoords  \
# 0  None
# 1  {'car': [{'rep': True, 'x': 126.923006, 'y': 37.550324}], 'walk': None}
# 2  {'car': [{'rep': True, 'x': 126.92334, 'y': 37.551351}], 'walk': None}
# 3  {'car': [{'rep': True, 'x': 126.923273, 'y': 37.551494}], 'walk': None}
# 4  None
#
#    hasBroadcastInfo  hasCardBenefit  hasNPay  hasNaverBooking  \
# 0  True              False           False    False
# 1  False             False           False    False
# 2  False             False           False    False
# 3  False             False           False    False
# 4  False             False           False    False
#
#                                 homePage        id index indoor  \
# 0  http://www.veraent.com/                13304957  0     None
# 1  http://www.clubevans.com/              11611824  1     None
# 2                                         20891000  2     None
# 3                                         11612019  3     None
# 4  https://www.facebook.com/clubfreebird  11574609  4     None
#
#   indoorPanorama insidePanorama interiorPanorama  isAdultBusiness  isCallLink  \
# 0  None           None           None             False            False
# 1  None           None           None             False            False
# 2  None           None           None             False            False
# 3  None           None           None             False            False
# 4  None           None           None             False            False
#
#    isPollingPlace isSite itemLevel                          ktCallMd  \
# 0  False           1      12        c160c028c782b85902c4af156082ea3a
# 1  False           1      12        bbb1afffef095f4b8bc94759945632e5
# 2  False           1      12        633d644ad2a2a1e65c35ac2c4fd84857
# 3  False           1      12        fb7710372aa6d5f842ab3b69960f1fcb
# 4  False           1      12        daffbdb567bf0290e8b6fe86d56ba285
#
#                       marker markerLabel             markerSelected menuExist  \
# 0  nres://marker/00036-00089  None        nres://marker/00036-00213  0
# 1  nres://marker/00038-00089  None        nres://marker/00038-00213  1
# 2  nres://marker/00034-00088  None        nres://marker/00034-00208  0
# 3  nres://marker/00037-00089  None        nres://marker/00037-00213  1
# 4  nres://marker/00036-00089  None        nres://marker/00036-00213  0
#
#   menuInfo michelinGuide microReview     name naverBookingUrl  \
# 0  None     None          []          베라
# 1  None     None          []          클럽에반스
# 2  None     None          []          NB2
# 3  None     None          []          클럽nb 홍대
# 4  None     None          []          클럽 프리버드
#
#   naverEasyOrderUrl parkingPrice petrolInfo  \
# 0  None              -1           None
# 1  None              -1           None
# 2  None              -1           None
# 3  None              -1           None
# 4  None              -1           None
#
#                                                                                                                                                                                                                poiInfo  \
# 0  {'relation': None, 'hasRelation': False, 'road': {'poiShapeType': '1', 'shapeKey': None, 'boundary': None, 'detail': None}, 'hasRoad': False, 'land': None, 'hasLand': False, 'polygon': None, 'hasPolygon': False}
# 1  {'relation': None, 'hasRelation': False, 'road': {'poiShapeType': '1', 'shapeKey': None, 'boundary': None, 'detail': None}, 'hasRoad': False, 'land': None, 'hasLand': False, 'polygon': None, 'hasPolygon': False}
# 2  {'relation': None, 'hasRelation': False, 'road': {'poiShapeType': '1', 'shapeKey': None, 'boundary': None, 'detail': None}, 'hasRoad': False, 'land': None, 'hasLand': False, 'polygon': None, 'hasPolygon': False}
# 3  {'relation': None, 'hasRelation': False, 'road': {'poiShapeType': '1', 'shapeKey': None, 'boundary': None, 'detail': None}, 'hasRoad': False, 'land': None, 'hasLand': False, 'polygon': None, 'hasPolygon': False}
# 4  {'relation': None, 'hasRelation': False, 'road': {'poiShapeType': '1', 'shapeKey': None, 'boundary': None, 'detail': None}, 'hasRoad': False, 'land': None, 'hasLand': False, 'polygon': None, 'hasPolygon': False}
#
#   posExact ppc rank region  reviewCount                        roadAddress  \
# 0  1        1   1    홍대 클럽  0            서울특별시 마포구 홍익로 25
# 1  1        1   2    홍대 클럽  0            서울특별시 마포구 와우산로 63
# 2  1        0   3    홍대 클럽  0            서울특별시 마포구 와우산로 76-1
# 3  1        1   4    홍대 클럽  0            서울특별시 마포구 와우산로 79
# 4  1        1   5    홍대 클럽  0            서울특별시 마포구 와우산로17길 19-22 DO빌딩 지하1층
#
#   shopWindowInfo                        shortAddress  \
# 0  None           [서울 마포구, 홍익로 25]
# 1  None           [서울 마포구, 와우산로 63]
# 2  None           [서울 마포구, 와우산로 76-1]
# 3  None           [서울 마포구, 와우산로 79]
# 4  None           [서울 마포구, 와우산로17길 19-22, DO빌딩 지하1층]
#
#                                                                                                                       skyPanorama  \
# 0  {'id': 'Hg+1tKAOibDvW7xjMwFF6Q==', 'pan': '155.91', 'tilt': '-30.00', 'lng': '126.9215393', 'lat': '37.5555573', 'fov': '124'}
# 1  {'id': 'yPOagQ95SNnx+G3CZBRQFA==', 'pan': '-2.06', 'tilt': '-30.00', 'lng': '126.9229736', 'lat': '37.5483322', 'fov': '124'}
# 2  {'id': 'VKH3kQ4tk6K/E16akkRcHw==', 'pan': '-7.96', 'tilt': '-30.00', 'lng': '126.9240112', 'lat': '37.5483322', 'fov': '124'}
# 3  {'id': 'yPOagQ95SNnx+G3CZBRQFA==', 'pan': '3.64', 'tilt': '-30.00', 'lng': '126.9229736', 'lat': '37.5483322', 'fov': '124'}
# 4  {'id': 'NFMflOeRptlbr+u20bchBw==', 'pan': '-11.47', 'tilt': '-30.00', 'lng': '126.9215164', 'lat': '37.5483322', 'fov': '124'}
#
#                                                                                                                    streetPanorama  \
# 0  {'id': 's3fcxqf1ZJOFPSrjwfqoOA==', 'pan': '154.41', 'tilt': '10.00', 'lng': '126.9219618', 'lat': '37.5546093', 'fov': '120'}
# 1  {'id': 'MPsXIRQp06SEqCPWEXITDg==', 'pan': '-33.16', 'tilt': '10.00', 'lng': '126.9230284', 'lat': '37.5502897', 'fov': '120'}
# 2  {'id': 'LVyxdGnd2TxvRN37QMm9qQ==', 'pan': '101.69', 'tilt': '10.00', 'lng': '126.9232740', 'lat': '37.5513646', 'fov': '120'}
# 3  {'id': 'U/Tt56LEWKpGoJNUncQbKg==', 'pan': '-120.37', 'tilt': '10.00', 'lng': '126.9233250', 'lat': '37.5515244', 'fov': '120'}
# 4  {'id': 'QdcaS8w99MiSVRDV8cTQ5g==', 'pan': '-91.45', 'tilt': '10.00', 'lng': '126.9214848', 'lat': '37.5493883', 'fov': '120'}
#
#   subway          tel   telDisplay theme  \
# 0  None   02-338-0957  02-338-0957  None
# 1  None   02-337-8361  02-337-8361  None
# 2  None                             None
# 3  None   02-326-1716  02-326-1716  None
# 4  None   02-335-4576  02-335-4576  None
#
#                                                                                  thumUrl  \
# 0  None
# 1  http://ldb.phinf.naver.net/20150831_275/1441004893369gYh5w_JPEG/11611824_0.jpg
# 2  None
# 3  http://ldb.phinf.naver.net/20150831_283/1441004925871FfVOB_JPEG/11612019_0.jpg
# 4  http://ldb.phinf.naver.net/20170515_61/14948242514334wCgL_JPEG/186465538750315_0.jpeg
#
#     type virtualTel            x           y      category_str  \
# 0  일반음식점             126.9220066  37.5545161  ['스포츠,오락', '클럽']
# 1  일반음식점             126.9229023  37.5503113  ['스포츠,오락', '클럽']
# 2  일반음식점             126.9235934  37.5513212  ['스포츠,오락', '클럽']
# 3  일반음식점             126.9231760  37.5515130  ['스포츠,오락', '클럽']
# 4  일반음식점             126.9213015  37.5493919  ['스포츠,오락', '클럽']
#
#          roadAddress_short abbrAddress_short
# 0  서울특별시 마포구 홍익로 25         서교동 356-1
# 1  서울특별시 마포구 와우산로 63        서교동 407-3
# 2  서울특별시 마포구 와우산로 76-1      서교동 361-18
# 3  서울특별시 마포구 와우산로 79        서교동 362-4
# 4  서울특별시 마포구 와우산로17길 19-22  서교동 408-16

# %% [markdown]
# # Columns

# %%
cols = ['name', 'region', 'type', 'roadAddress', 'x', 'y']

# %%
club.loc[::, cols]
# Out:
#                      name  region   type                          roadAddress  \
