# %%
import pandas as pd

from src.common import get_df_from_excel
from src.club import dir_item, dir_proj, dir_tableau
from src.club import file_excels, file_tsvs
from src.club import convert_excel_to_tsv


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# def convert_excel_to_tsv(path_dir, file_excel, file_tsv):
#     df = get_df_from_excel(path_dir + file_excel)
#     df.to_csv(path_dir + file_tsv, sep='\t', index=False)

# def add_gu_and_export(file_path, ):
#     def get_gu_from_row(row):
#         for gu in SEOUL_GU:
#             if (gu in row['소재지전체주소']) or (gu in row['도로명전체주소']):
#                 return gu
#         else:
#             return ''
#     df['소재지전체주소'].fillna('', inplace=True)
#     df['도로명전체주소'].fillna('', inplace=True)
#     df['자치구'] = df.apply(get_gu_from_row, axis=1)
#     df.head()
#     df.to_csv(file_path, sep='\t', index=False)

# def export_big_three_gu(path_dir, file_name_ext):
#     import os
#     file_name, file_ext = os.path.splitext(file_name_ext)
#     df = pd.read_csv(path_dir + file_name_ext, sep='\t')
#     df = df.loc[df['자치구'].isin(['강남구', '마포구', '용산구'])]
#     df.to_csv(path_dir + file_name + '_big_three_gu' + file_ext, sep='\t', index=False)

# %%
file_index = 2
file_excel = file_excels[file_index]
file_tsv = file_tsvs[file_index]


convert_excel_to_tsv(dir_proj, file_excel, file_tsv)

# %%
df = get_df_from_excel(dir_proj + file_excel)
df.head()
# Out:
#    번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0   1  휴게음식점  07_24_05_P   3000000  3000000-104-1998-09983  19980615      NaN
# 1   2  휴게음식점  07_24_05_P   3000000  3000000-104-1998-09984  19980615      NaN
# 2   3  휴게음식점  07_24_05_P   3000000  3000000-104-1998-08873  19980626      NaN
# 3   4  휴게음식점  07_24_05_P   3000000  3000000-104-1998-08933  19980701      NaN
# 4   5  휴게음식점  07_24_05_P   3000000  3000000-104-2003-00032  20030425      NaN
#
#    영업상태구분코드 영업상태명  상세영업상태코드  ... 공장판매직종업원수  공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 0         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 1         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 2         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 3         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
# 4         3    폐업         2  ...       NaN        NaN      NaN  NaN  NaN
#
#   다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지
# ...

# %%
df.head(100)
# Out:
#      번호  개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  \
# 0     1  유흥주점영업  07_23_02_P   3000000  3000000-102-1974-08338  19741023
# 1     2  유흥주점영업  07_23_02_P   3000000  3000000-102-1974-08313  19740625
# 2     3  유흥주점영업  07_23_02_P   3000000  3000000-102-1974-08323  19740607
# 3     4  유흥주점영업  07_23_02_P   3000000  3000000-102-1974-08231  19740530
# 4     5  유흥주점영업  07_23_02_P   3000000  3000000-102-1974-08292  19740510
# 5     6  유흥주점영업  07_23_02_P   3000000  3000000-102-1999-11779  19991218
# 6     7  유흥주점영업  07_23_02_P   3000000  3000000-102-1999-10964  19991218
# 7     8  유흥주점영업  07_23_02_P   3000000  3000000-102-1985-08261  19850122
# 8     9  유흥주점영업  07_23_02_P   3000000  3000000-102-1984-08276  19841006
# 9    10  유흥주점영업  07_23_02_P   3000000  3000000-102-1984-08322  19840921
# 10   11  유흥주점영업  07_23_02_P   3000000  3000000-102-1984-11439  19840908
# 11   12  유흥주점영업  07_23_02_P   3000000  3000000-102-1984-08265  19840908
# ...
